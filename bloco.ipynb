# %%
import pdfplumber
import re
import glob
import pandas as pd
import os

# %%
# a) Defina o diretório onde estão os PDFs
pdf_dir   = r'D:\Fausto Stangler\Downloads\bloco'
# b) Liste todos os arquivos .pdf nessa pasta
pdf_paths = glob.glob(os.path.join(pdf_dir, '*.pdf'))
pdf_paths
# Out:
# ['D:\\Fausto Stangler\\Downloads\\bloco\\CENTRO CIRURGICO - SUS.pdf',
#  'D:\\Fausto Stangler\\Downloads\\bloco\\escala 30 de abril - privado.pdf']

# %%
def text_from_pdf(path):
    """Retorna uma lista com cada linha de texto extraída do PDF."""
    lines = []
    with pdfplumber.open(path) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            if text:
                # splitlines preserva corretamente cada quebra de linha
                lines.extend(text.splitlines())
    return lines

# %%
content = []
for p in pdf_paths:
    content.append(text_from_pdf(p))
content
# Out:
# [['11 - HOSPITAL BANCO DE OLHOS ASSOCIACAO Página: 1 /11',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: CIBELE.SILVA',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:48',
#   'Data: 30/04/2025',
#   'Centro Cirúrgico : 9 - CENTRO CIRURGICO - SUS',
#   'Sala : 24 - SALA 1',
#   'Hora Aviso Atend. Tipo Paciente Idade Telefone Leito UTI Rad. Prestador\\Atividade',
#   '15:00 44293 Internação 320234 PERLA CHAVES ALTAMIRANDA 37 Não Não AMANDA SCHNORR',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - INTERNACAO/PLANO UNICO Não Cadastrado',
#   'VITRECTOMIA POSTERIOR COM INFUSAO DE PERFLUOCARBONO E E Esquerda SUS - INTERNACAO Não Cadastrado',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '16:00 44294 Internação 322520 ERONI MORAIS DE OLIVEIRA 76 54 999510942 Não Não AMANDA SCHNORR',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'VITRECTOMIA POSTERIOR COM INFUSAO DE PERFLUOCARBONO E E Direita SUS - INTERNACAO Não Cadastrado',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'Sala : 25 - SALA 2',
#   'Hora Aviso Atend. Tipo Paciente Idade Telefone Leito UTI Rad. Prestador\\Atividade',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '11 - HOSPITAL BANCO DE OLHOS ASSOCIACAO Página: 2 /11',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: CIBELE.SILVA',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:48',
#   'Data: 30/04/2025',
#   '15:30 44321 Ambulatorial 320965 ROSINARA GARCIA ANTUNES 57 998680979 Não Não LUIZ EDUARDO OSOWSKI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO Não Cadastrado',
#   'Observação: BIO C/ MÉDICO',
#   'Tipo(s) de Anestesia: LOCAL',
#   '16:00 44310 Ambulatorial 220766 JORGE SOARES SIQUEIRA 66 51 985756176 Não Não LUIZ EDUARDO OSOWSKI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO Não Cadastrado',
#   'Observação: BIO C/ MÉDICO',
#   'Tipo(s) de Anestesia: LOCAL',
#   '16:30 44248 Ambulatorial EVA MARLI MORAES DOS SANTOS Não Não LUIZ EDUARDO OSOWSKI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: BIO C/ O MEDICO',
#   'Tipo(s) de Anestesia: LOCAL',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '11 - HOSPITAL BANCO DE OLHOS ASSOCIACAO Página: 3 /11',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: CIBELE.SILVA',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:48',
#   'Data: 30/04/2025',
#   '17:00 44285 Ambulatorial LEDA MARIA ADAME JENUINO Não Não LUIZ EDUARDO OSOWSKI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: BIO C/ O MEDICO',
#   'Tipo(s) de Anestesia: LOCAL',
#   '17:30 44313 Ambulatorial ORVANDIL SILVA JARDIM Não Não LUIZ EDUARDO OSOWSKI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO Não Cadastrado',
#   'Observação: BIO C/ MÉDICO',
#   'Tipo(s) de Anestesia: LOCAL',
#   '18:00 44314 Ambulatorial 224081 EDISON DA SILVA OLIVEIRA 62 51 998251519 Não Não LUIZ EDUARDO OSOWSKI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO Não Cadastrado',
#   'Observação: BIO C/ MÉDICO',
#   'Tipo(s) de Anestesia: LOCAL',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '11 - HOSPITAL BANCO DE OLHOS ASSOCIACAO Página: 4 /11',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: CIBELE.SILVA',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:48',
#   'Data: 30/04/2025',
#   '18:30 44315 Ambulatorial 222429 MARCO AURELIO AMARAL BAYER 56 51 993530969 Não Não LUIZ EDUARDO OSOWSKI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO Não Cadastrado',
#   'Observação: BIO C/ MÉDICO',
#   'Tipo(s) de Anestesia: LOCAL',
#   '19:00 44317 Ambulatorial MARLEI SIMAO BARBOSA Não Não LUIZ EDUARDO OSOWSKI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO Não Cadastrado',
#   'Observação: BIO C/ MÉDICO',
#   'Tipo(s) de Anestesia: LOCAL',
#   '19:30 44319 Ambulatorial 223665 EDISON RICARDO PEREIRA SILVA 66 41 988640252 Não Não LUIZ EDUARDO OSOWSKI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO Não Cadastrado',
#   'Observação: BIO C/ MÉDICO',
#   'Tipo(s) de Anestesia: LOCAL',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '11 - HOSPITAL BANCO DE OLHOS ASSOCIACAO Página: 5 /11',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: CIBELE.SILVA',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:48',
#   'Data: 30/04/2025',
#   '20:00 44281 Ambulatorial IARA APARECIDA DA COSTA Não Não LUIZ EDUARDO OSOWSKI',
#   'SALGADO',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: LIO LEEDSAY 19,50/ DRA SUZANE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '20:30 44283 Ambulatorial SIONI BITTENCOURT FRAGA Não Não LUIZ EDUARDO OSOWSKI',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: LIO LEEDSAY 20,00 / MANITOL NO PRE / DRA SUZANE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '21:00 44291 Ambulatorial MARIA DE LOURDES MARTINS (51)999006317 Não Não LUIZ EDUARDO OSOWSKI',
#   'BORCHARTT',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO Não Cadastrado',
#   'Observação: LIO LEEDSAY +18,50 / DR. ANDRE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'Sala : 26 - SALA 3',
#   'Hora Aviso Atend. Tipo Paciente Idade Telefone Leito UTI Rad. Prestador\\Atividade',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '11 - HOSPITAL BANCO DE OLHOS ASSOCIACAO Página: 6 /11',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: CIBELE.SILVA',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:48',
#   'Data: 30/04/2025',
#   '08:00 44279 Ambulatorial 300112 LARISSA MANUELI REIS BRAZ 7 55 997089328 Não Não JULIA MARIA LUNELLI',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'CORREÇÃO CIRÚRGICA DO ESTRABISMO (ATE 2 MUSCULOS) Bilateral SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: 7 ANOS',
#   'Tipo(s) de Anestesia: GERAL',
#   '09:00 44280 Ambulatorial ADEMIR ANDRE DOS SANTOSS Não Não JULIA MARIA LUNELLI',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'CORREÇÃO CIRÚRGICA DO ESTRABISMO (ATE 2 MUSCULOS) Bilateral SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '17:00 44290 Ambulatorial 222428 LIRIA SOARES BARBOSA 72 51 986201584 Não Não LUIZ EDUARDO OSOWSKI',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM IMPLANTE DE LENTE INTRA-OCULAR Direita SUS - AMBULATORIO Não Cadastrado',
#   'Observação: LIO VISION +21,50 / MANITOL NO PRÉ / DR. DANIEL',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'Sala : 28 - SALA 5',
#   'Hora Aviso Atend. Tipo Paciente Idade Telefone Leito UTI Rad. Prestador\\Atividade',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '11 - HOSPITAL BANCO DE OLHOS ASSOCIACAO Página: 7 /11',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: CIBELE.SILVA',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:48',
#   'Data: 30/04/2025',
#   '08:00 44307 Ambulatorial VILMA ZANG HORST Não Não BRUNA NUNES PAGANO',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: LIO LEEDSAY 22,50 / DRA SUZANE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '09:00 44312 Internação LURDES TEREZINHA VIEIRA Não Não BRUNA NUNES PAGANO',
#   'PEREIRA',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: LIO LEEDSAY 20,00 / DRA SUZANE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '10:00 44332 Ambulatorial MARIA ERONI SILVA CONRADO Não Não BRUNA NUNES PAGANO',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: LIO LEEDSAY 21,50 / MANITOL NO PRE / DRA SUZANE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '11 - HOSPITAL BANCO DE OLHOS ASSOCIACAO Página: 8 /11',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: CIBELE.SILVA',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:48',
#   'Data: 30/04/2025',
#   '11:00 44309 Ambulatorial GENI VITT Não Não BRUNA NUNES PAGANO',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: LIO LEEDSAY 24,50 / MANITOL NO PRE / DR ANDRE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '12:00 44311 Ambulatorial MARIA CLENI RASKI PEREIRA Não Não BRUNA NUNES PAGANO',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   '2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: LIO LEEDSAY 20,50 / DR ANDRE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '15:00 44333 Internação DANIEL CARVALHO RUBECCHINI Não Não KARLA LINCK SCHEID',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'RETINOPEXIA C/INTROF ESCLERAL (QQ TECNIC Esquerda SUS - INTERNACAO/PLANO UNICO Não Cadastrado',
#   'VITRECTOMIA POSTERIOR COM INFUSAO DE PERFLUO/OLEO DE SILI Esquerda SUS - INTERNACAO/PLANO UNICO Não Cadastrado',
#   'Observação: BIO NO DIA',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'Total de Avisos de Cirurgia : 23',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '11 - HOSPITAL BANCO DE OLHOS ASSOCIACAO Página: 9 /11',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: CIBELE.SILVA',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:48',
#   'Data: 30/04/2025',
#   'Centro Cirúrgico : 10 - SALA 08',
#   'Sala : 31 - SALA 08',
#   'Hora Aviso Atend. Tipo Paciente Idade Telefone Leito UTI Rad. Prestador\\Atividade',
#   '08:00 44252 Ambulatorial 322611 ENIO RODRIGUES DE MORAES 73 51 33643730 Não Não MATEUS LUIS RIEDI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: NÃO JUDICIALIZADA - H35.3 - *AVASTIN*',
#   'OLHO ESQUERDO - 1° APLICAÇÃO - CONFIRMAFA EM 28/04/25 - CHEGAR AS 07:15',
#   'Tipo(s) de Anestesia: LOCAL',
#   '08:15 44243 Ambulatorial 322579 DEJAIR CABRAL GONCALVES 74 Não Não MATEUS LUIS RIEDI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: NÃO JUDICIALIZADA - H35.3 - *AVASTIN*',
#   'OLHO DIREITO - 1° APLICAÇÃO - CONFIRMADA EM 28/04/25 - CHEGAR AS 07:15',
#   'Tipo(s) de Anestesia: LOCAL',
#   '08:30 44211 Ambulatorial 322513 MARIA GORETE DE VARGAS ALLOY 65 51 991108932 Não Não MATEUS LUIS RIEDI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: NÃO JUDICIALIZAA - H35.3 - *AVASTIN*',
#   'OLHO DIREITO - 1° APLICAÇÃO - CONFIRMADA EM 28/04/25 - CHEGAR AS 07:15',
#   'Tipo(s) de Anestesia: LOCAL',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '11 - HOSPITAL BANCO DE OLHOS ASSOCIACAO Página: 10 /11',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: CIBELE.SILVA',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:48',
#   'Data: 30/04/2025',
#   '08:45 41002 Ambulatorial 129626 LEONARDO DIAS CONSTANTE 31 51 996697438 Não Não EDUARDO TAUBE BORRE',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: NÃO JUDICIALIZADA - H35.3 - *AVASTIN*',
#   'OLHO ESQUERDO - 2° APLICAÇÃO CONFIRMADA COM PACIENTE EM 03/03/25 - CHEGAR AS 07:00',
#   'Tipo(s) de Anestesia: LOCAL',
#   '09:00 40126 Ambulatorial 261711 VILSON DE JESUS NORONHA DE 52 Não Não EDUARDO TAUBE BORRE',
#   'FREITAS',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: NÃO JUDICIALIZADA - H35.3 - *AVASTIN*',
#   'OLHO ESQUERDO - 3° APLICAÇÃO - CONFIRMADA COM JUSSARA FAMILIAR - CHEGAR AS 07:00',
#   'Tipo(s) de Anestesia: LOCAL',
#   '09:15 41144 Ambulatorial 262367 NELOI ANTUNES MACHADO 68 55 996786406 Não Não MATEUS LUIS RIEDI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: NÃO JUDICIALIZADA - H35.3 - *AVASTIN*',
#   'OLHO DIREITO - 2° APLICAÇÃO - CONFIRMADA EM 05/03/25 - CHEGAR AS 07:00 HORAS',
#   'Tipo(s) de Anestesia: LOCAL',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '11 - HOSPITAL BANCO DE OLHOS ASSOCIACAO Página: 11 /11',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: CIBELE.SILVA',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:48',
#   'Data: 30/04/2025',
#   '09:30 44155 Ambulatorial 312868 ALTAIR LEOPOLDO DIAS 71 51 999802104 Não Não MATEUS LUIS RIEDI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: NÃO JUDICILIAZIDA - H35.3 - *AVASTIN*',
#   'OLHO DIREITO - 1° APLICAÇÃO - CONFIRMADA EM 28/04/25 - CHEGAR AS 07:00',
#   'Tipo(s) de Anestesia:',
#   '09:45 44195 Ambulatorial 322477 EDITI NELI DA SILVA 66 51 999461828 Não Não MATEUS LUIS RIEDI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: NÃO JUDICILAIZADA - H35.3 - *AVASTIN*',
#   'OLHO DIREITO - 1° APLICAÇÃO - CONFIRMADA COM CAMILA AGENTE DE SAUDE - CHEGAR AS 07:15',
#   'Tipo(s) de Anestesia: LOCAL',
#   '10:00 44260 Ambulatorial 220288 JAIR HOMEM DE LIMA 55 51 995113641 Não Não MATEUS LUIS RIEDI',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado',
#   'Observação: NÃO JUDICIALIZADA - H35.3 - *AVASTIN*',
#   'OLHO DIREITO - 1° APLICAÇÃO - CONFIRMADA EM 28/04/25 - CHEGAR AS 07:15',
#   'Tipo(s) de Anestesia: LOCAL',
#   'Total de Avisos de Cirurgia : 32',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS'],
#  ['10 - HOSPITAL BANCO DE OLHOS LTDA Página: 1 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:19',
#   'Data: 30/04/2025',
#   'Centro Cirúrgico : 7 - C. CIRURGICO-LTDA',
#   'Sala : 17 - SALA 1',
#   'Hora Aviso Atend. Tipo Paciente Idade Telefone Leito UTI Rad. Prestador\\Atividade',
#   '09:00 43207 Ambulatorial 309067 CLAUDIO OLIVEIRA CHEVARRIA 71 Não Não FELIPE FERNANDES NICOLA',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda CANOASPREV/PLANO UNICO Autorizado',
#   'Observação: PACIENTE EXTERNO/UNIDADE MAX PLAZA LIO MA60AC+23,00 (3 PEÇAS)/PACIENTE ACERTA 15% DE COOPARTICIPAÇÃO NO HBO',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '13:00 43531 Internação 183636 DAVID PERACHI DE BARCELLOS DA 58 51 984994741 Não Não AMANDA SCHNORR',
#   'SILVA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO/ EYLIA',
#   'Tipo(s) de Anestesia: LOCAL',
#   '13:30 43532 Ambulatorial 136586 JANETE BORGES DE VARGAS 63 51 996377605 Não Não AMANDA SCHNORR',
#   'FERREIRA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 3 Autorizado',
#   'Observação: PACIENTE INTENRO/ EYLIA',
#   'Tipo(s) de Anestesia: LOCAL',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 2 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:19',
#   'Data: 30/04/2025',
#   '14:00 43533 Ambulatorial 284667 NADYR DALTRO MILTON 88 51 997394030 Não Não AMANDA SCHNORR',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTENRO/ EYLIA',
#   'Tipo(s) de Anestesia: LOCAL',
#   '14:30 43536 Ambulatorial 129399 CARLOS ALBERTO ESPINOZA DE 57 55 51 985217073 Não Não AMANDA SCHNORR',
#   'FREITAS',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 3 Autorizado',
#   'Observação: PACIENTE INTERNO/ EYLIA',
#   'Tipo(s) de Anestesia: LOCAL',
#   '15:00 44316 Ambulatorial 196530 SILVIA LETICIA DUTRA MELLES 50 Não Não AMANDA SCHNORR',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'PCT PART TRATAMENTO OCULAR QUIMIOTERAPICO Direita PARTICULAR Não Cadastrado',
#   'Observação: PACIENTE CONCIERGE / PACIENTE ACERTA TAXA + HONORÁRIOS VIA HOSPITAL / MED FRAC',
#   'Tipo(s) de Anestesia: LOCAL',
#   'Sala : 18 - SALA 2',
#   'Hora Aviso Atend. Tipo Paciente Idade Telefone Leito UTI Rad. Prestador\\Atividade',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 3 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:19',
#   'Data: 30/04/2025',
#   '07:30 43652 Ambulatorial 306385 PAULO ROBERTO GUICHARD 72 51 992777457 Não Não OTAVIO DE AZEVEDO MAGALHAES',
#   'FREIRE',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda UNIMED HOSPITAL/UNIMAX Autorizado',
#   'Observação: PACIENTE EXTERNO/ HOYA VIVINEX IMPRESS +23,50 (FOCO ESTENDIDO)/MÉDICO ACERTA/ LIFE EQUIPA/ SN:4WP615K6/ HOYA',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '08:30 44266 Internação 174138 TANIA REGINA AITA DE MEDEIROS 76 44 991498544 Não Não OTAVIO DE AZEVEDO MAGALHAES',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'IRIDECTOMIA (LASER OU CIRURGICA) - MONOCULAR Esquerda SULMED/PLANO UNICO Autorizado',
#   'TRANSPLANTE DE CORNEA - COMBINADA Esquerda SULMED/PLANO UNICO Autorizado',
#   'Observação: PACIENTE INTERNO RGCT: 463168-143 OD',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '10:00 44169 Ambulatorial 197761 LUIS LASSANCE MOREIRA 80 51 999157448 Não Não OTAVIO DE AZEVEDO MAGALHAES',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'RECONSTRUCAO CAMARA ANTERIOR Esquerda UNIMED HOSPITAL/UNIPART Autorizado',
#   'Observação: PACIENTE INTERNO',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 4 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:19',
#   'Data: 30/04/2025',
#   '12:00 44295 Ambulatorial MARIO ALEXANDRE RAMOS Não Não ADRIANO CALCAGNOTTO GARCIA',
#   'CARDOSO',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'CANTOPLASTIA LATERAL Bilateral UNIMED HOSPITAL Autorizado',
#   'DERMATOCALAZE OU BLEFAROCALAZE – UNILATERAL Bilateral UNIMED HOSPITAL Autorizado',
#   'Observação: PACIENTE EXTERNO',
#   'PTOSE PALPEBRAL - CORRECAO CIRURGICA - UNILATERAL Bilateral UNIMED HOSPITAL Autorizado',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '12:30 43640 Ambulatorial MARIO ALEXANDRE RAMOS Não Não ADRIANO CALCAGNOTTO GARCIA',
#   'CARDOSO',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'PCT PART BLEFAROPLASTIA SUPERIOR OU INFERIOR AO Bilateral PARTICULAR Não Cadastrado',
#   'Observação: PACIENTE EXTERNO/ PACIENTE ACERTA',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 5 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:19',
#   'Data: 30/04/2025',
#   '15:00 43900 Ambulatorial 140367 CONCEICAO MARIA QUADROS 75 Não Não ANAIS BACK DA SILVA',
#   'SANTOS',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'CIRURGIAS FISTULIZANTES ANTIGLAUCOMATOSAS Direita IPERGS/CATEGORIA 5 Autorizado',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO/LIO MA60AC + 27,50(3 PEÇAS)',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'Sala : 19 - SALA 3',
#   'Hora Aviso Atend. Tipo Paciente Idade Telefone Leito UTI Rad. Prestador\\Atividade',
#   '10:00 43976 Ambulatorial 319267 NEURI ZWIRTES 49 Não Não JULIA MARIA LUNELLI',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'PCT PART ESTRABISMO (MONO) Direita PARTICULAR Não Cadastrado',
#   'Observação: PACIENTE ACERTA / PACIENTE CONCIERGE /',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 6 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:19',
#   'Data: 30/04/2025',
#   '13:00 44187 Ambulatorial 300491 MARLENE GONCALVES DA SILVA 85 Não Não KAROLINY KRAUSE MONICO',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'RECONST. DE VIAS LACRIMAIS COM SILICONE OU OUTRO MATERIAL Esquerda IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '18:00 44092 Ambulatorial CLAUDIA SOIR Não Não DELANO JORGE',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'ECTROPIO Bilateral IPERGS/CATEGORIA 4 Autorizado',
#   'PALPEBRA - RECONSTRUCAO PARCIAL (COM OU SEM RESSECCAO D Bilateral IPERGS/CATEGORIA 4 Autorizado',
#   'RECONST. DE VIAS LACRIMAIS COM SILICONE OU OUTRO MATERIAL Bilateral IPERGS/CATEGORIA 4 Autorizado',
#   'Observação: PACIENTE EXTERNO',
#   'Tipo(s) de Anestesia: SEDACAO',
#   'Sala : 20 - SALA 4',
#   'Hora Aviso Atend. Tipo Paciente Idade Telefone Leito UTI Rad. Prestador\\Atividade',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 7 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:19',
#   'Data: 30/04/2025',
#   '08:00 43097 Ambulatorial ROZIMERI MACHADO BARROS Não Não DANIEL EMILIO VALENZUELA CHIRINOS',
#   'SAM',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita DOCTOR CLIN Autorizado',
#   'Observação: PACIENTE EXTERNO/ LIO MA60AC + 18,50(3 PEÇAS)',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '09:30 42882 Ambulatorial 313486 DEISI LUCIA MACHADO PASSOS 66 Não Não JULIA TEIXEIRA LEITE PEREIRA',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: LIO MA60AC +24.50 (3 PEÇAS) / PACIENTE CONCIERGE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '11:30 43116 Ambulatorial 308599 RUDI NEI DAL MOLIN 77 51 997230563 Não Não VICTORIA D AZEVEDO SILVEIRA',
#   'VINICIUS KHATIB NEVES',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda CASSI/PLANO ASSOCIADO Autorizado',
#   'Observação: PACIENTE INTERNO / LIO MA60AC +16,50 (3 PEÇAS)',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 8 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:19',
#   'Data: 30/04/2025',
#   '12:00 43829 Ambulatorial EVA SUSANY ALLGAYER Não Não VICTORIA D AZEVEDO SILVEIRA',
#   'VINICIUS KHATIB NEVES',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS Autorizado',
#   'Observação: PACIENTE EXTERNO/ HOYA VIVINEX TORIC +25.0 T2 (TÓRICA)/NÃO BLOQUEAR/ MÉDICA ACERTA/ LIFE EQUIPA/ SN:2EPY01C2/ HOYA',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '12:30 43911 Ambulatorial 317083 ANTONIO PAULO FERREIRA 76 Não Não VICTORIA D AZEVEDO SILVEIRA',
#   'VINICIUS KHATIB NEVES',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'PCT PART FACECTOMIA COM LENTE INTRA-OCULAR (S/LIO) Direita PARTICULAR Não Cadastrado',
#   'Observação: LIO MA60AC (3 PECAS) 23.00 / PACIENTE ACERTA TAXA + LIO + HONORÁRIOS VIA HOSPITAL / PACIENTE CONCIERGE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '13:00 43522 Ambulatorial 206573 MARIA LUIZA DE OLIVEIRA 62 51 980400710 Não Não VICTORIA D AZEVEDO SILVEIRA',
#   'KRIGGER',
#   'VINICIUS KHATIB NEVES',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: LIO ISERT 255(ASFERICA) +23.50 / PACIENTE ACERTA / PACIENTE CONCIERGE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 9 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:19',
#   'Data: 30/04/2025',
#   '14:00 43711 Ambulatorial NOELY INES LUFT Não Não JAMES DA COSTA MARCHIORI',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'ESTRABISMO HORIZONTAL - MONOCULAR - TTO CIRURGICO Esquerda UNIMED HOSPITAL Autorizado',
#   'Observação: PACIENTE EXTERNO',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '15:00 43712 Ambulatorial ANA FLAVIA IONG DA SILVA Não Não JAMES DA COSTA MARCHIORI',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'ESTRABISMO HORIZONTAL - MONOCULAR - TTO CIRURGICO Esquerda UNIMED HOSPITAL Autorizado',
#   'Observação: PACIENTE EXTERNO',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'Sala : 21 - SALA 5',
#   'Hora Aviso Atend. Tipo Paciente Idade Telefone Leito UTI Rad. Prestador\\Atividade',
#   '13:00 43865 Ambulatorial 127670 JOAO OLIVEIRA DE VARGAS 79 51 997079459 Não Não GUSTAVO SANGALLI KUSSLER',
#   'SEA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS/CATEGORIA 2 Autorizado',
#   'Observação: PACIENTE INTERNO / LIO SENSAR 21,50 (3 PEÇAS)',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 10 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:19',
#   'Data: 30/04/2025',
#   '13:30 44225 Ambulatorial 321267 MARCO ANTONIO SCHNEIDER DE 68 Não Não GUSTAVO SANGALLI KUSSLER',
#   'ALMEIDA',
#   'SEA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: LIO MA60AC + 22.50 (3 PEÇAS) / PACIENTE CONCIERGE',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '17:30 43993 Ambulatorial LOURDES MARIA SANCHES Não Não GABRIEL DOS SANTOS GATTI',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS Autorizado',
#   'Observação: PACIENTE EXTERNO / CT LUCIA +25,00 (ASFERICA) / MÉDICO ACERTA / RAYNER/ LIFE EQUIPA/ SN:6S2320380032/RAYNER',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   '18:00 43994 Ambulatorial 306611 ELIANE LUZENI HOMEM COSTA 53 Não Não GABRIEL DOS SANTOS GATTI',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO / LIO SENSAR 20,50 (3 PEÇAS) JONHSON',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 11 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:20',
#   'Data: 30/04/2025',
#   '18:30 43995 Ambulatorial 314191 ALINE SABRINA KORNDORFER 44 Não Não GABRIEL DOS SANTOS GATTI',
#   'VARGAS',
#   'COORE PARASTCHUK E VDS ANESTESIA',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO / LIO SENSAR 23,50 (3 PEÇAS) JONHSON',
#   'Tipo(s) de Anestesia: BLOQUEIO LOCAL + SEDACAO',
#   'Total de Avisos de Cirurgia : 28',
#   'Centro Cirúrgico : 8 - C. CIRURGICO-LTDA SL 8',
#   'Sala : 23 - SALA 8',
#   'Hora Aviso Atend. Tipo Paciente Idade Telefone Leito UTI Rad. Prestador\\Atividade',
#   '12:30 41919 Ambulatorial 177038 IRENE MILCHAREK GELAIN 71 51 998407663 Não Não GUSTAVO SANGALLI KUSSLER',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO/ EYLIA',
#   'Tipo(s) de Anestesia: LOCAL',
#   '12:45 41920 Ambulatorial 132891 IRAJA MARTINS DE ARAUJO 62 51 986149081 Não Não GUSTAVO SANGALLI KUSSLER',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO/ LUCENTIS',
#   'Tipo(s) de Anestesia: LOCAL',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 12 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:20',
#   'Data: 30/04/2025',
#   '13:00 42396 Ambulatorial 151823 SONIA MEDEIROS GOMES 78 51 981313462 Não Não GUSTAVO SANGALLI KUSSLER',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO / EYLIA',
#   'Tipo(s) de Anestesia: LOCAL',
#   '13:15 42397 Ambulatorial 151823 SONIA MEDEIROS GOMES 78 51 981313462 Não Não GUSTAVO SANGALLI KUSSLER',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO / EYLIA',
#   'Tipo(s) de Anestesia: LOCAL',
#   '13:30 42398 Ambulatorial 171776 VIVIANE JACQUES VIANNA 53 Não Não GUSTAVO SANGALLI KUSSLER',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO / LUCENTIS',
#   'Tipo(s) de Anestesia: LOCAL',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 13 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:20',
#   'Data: 30/04/2025',
#   '13:45 42405 Ambulatorial 300175 MOZART ARRUDA 65 55 51 986254901 Não Não GUSTAVO SANGALLI KUSSLER',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 3 Autorizado',
#   'Observação: PACIENTE EXTERNO / LUCENTIS',
#   'Tipo(s) de Anestesia: LOCAL',
#   '14:00 42406 Ambulatorial 300175 MOZART ARRUDA 65 55 51 986254901 Não Não GUSTAVO SANGALLI KUSSLER',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 3 Autorizado',
#   'Observação: PACIENTE EXTERNO / LUCENTIS',
#   'Tipo(s) de Anestesia: LOCAL',
#   '14:15 42407 Ambulatorial 130605 MARGOTE LUIZ DE SOUZA 62 51 992284390 Não Não GUSTAVO SANGALLI KUSSLER',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 3 Autorizado',
#   'Observação: PACIENTE INTERNO / LUCENTIS',
#   'Tipo(s) de Anestesia: LOCAL',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 14 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:20',
#   'Data: 30/04/2025',
#   '14:30 43054 Ambulatorial 134777 MARISA DE OLIVEIRA COELHO 69 51 34214031 Não Não GUSTAVO SANGALLI KUSSLER',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Bilateral ISSEG/PLANO UNICO Autorizado',
#   'Observação: PACIENTE INTERNO/ EYLIA',
#   'Tipo(s) de Anestesia: LOCAL',
#   '14:45 43055 Ambulatorial 305107 JOSE CARLOS LUDWIG 68 51 999269822 Não Não GUSTAVO SANGALLI KUSSLER',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita UNIMED HOSPITAL/CO-IRMA Autorizado',
#   'Observação: PACIENTE INTERNO / EYLIA',
#   'Tipo(s) de Anestesia: LOCAL',
#   '15:00 44200 Ambulatorial 210820 NARA REJANE TAVARES FEIJO 66 51 985042086 Não Não GUSTAVO SANGALLI KUSSLER',
#   'NUNES',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO / LUCENTIS',
#   'Tipo(s) de Anestesia: LOCAL',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS',
#   'MV | SoulMV',
#   '10 - HOSPITAL BANCO DE OLHOS LTDA Página: 15 /15',
#   'SOULMV - Sistema de Centro Cirúrgico e Obstétrico Emitido por: LARISSA.FEIJO',
#   'Relatório de Mapa Cirúrgico Em: 29/04/2025 17:20',
#   'Data: 30/04/2025',
#   '15:15 44202 Ambulatorial 210820 NARA REJANE TAVARES FEIJO 66 51 985042086 Não Não GUSTAVO SANGALLI KUSSLER',
#   'NUNES',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 5 Autorizado',
#   'Observação: PACIENTE INTERNO / LUCENTIS',
#   'Tipo(s) de Anestesia: LOCAL',
#   '15:30 44274 Ambulatorial ODELI GARCIA SILVA Não Não GUSTAVO SANGALLI KUSSLER',
#   'Cirurgia Lateralidade Convênio / Plano Sub-Plano Status Autorização',
#   'TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS Autorizado',
#   'Observação: PACIENTE EXTERNO / EYLIA',
#   'Tipo(s) de Anestesia: LOCAL',
#   'Total de Avisos de Cirurgia : 41',
#   'GRUPO SÃO PIETRO HOSPITAIS E CLÍNICAS']]

# %%
def clean_content(content):
    """
    Limpa o conteúdo das páginas, removendo linhas que não pertencem à escala
    e separa as linhas de controle (Total de Avisos de Cirurgia).
    
    Args:
        content: lista de páginas, cada página é lista de linhas (strings).
    
    Returns:
        tuple:
            cleaned_content: mesma estrutura de páginas, sem as linhas de cabeçalho/rodapé
            control_lines: lista de todas as linhas de 'Total de Avisos de Cirurgia'
    """
    cleaned_content = []
    control_lines = []
    
    # Padrões de linhas a remover
    header_patterns = [
        r'^\d+\s*-\s*HOSPITAL',              # "11 - HOSPITAL BANCO..."
        r'^SOULMV',                          # "SOULMV - Sistema..."
        r'^Relatório de Mapa Cirúrgico',     # Título do relatório
        r'^GRUPO',                           # "GRUPO SÃO PIETRO..."
        r'^MV\s*\|',                         # "MV | SoulMV"
    ]
    # Padrão de linha de controle
    control_pattern = re.compile(r'^Total de Avisos de Cirurgia\s*:\s*\d+', re.IGNORECASE)
    
    for page in content:
        cleaned_page = []
        for line in page:
            line_stripped = line.strip()
            # Se for linha de controle, salva e não inclui no cleaned_page
            if control_pattern.match(line_stripped):
                control_lines.append(line_stripped)
                continue
            # Se bater qualquer header_pattern, descarta
            if any(re.match(pat, line_stripped, re.IGNORECASE) for pat in header_patterns):
                continue
            # Caso contrário, mantém na página limpa
            cleaned_page.append(line)
        cleaned_content.append(cleaned_page)
    
    return cleaned_content, control_lines

# Exemplo de uso:
content, controls = clean_content(content)

# %%
def extract_last_controls_per_doc(content):
    """
    Para cada documento (lista de páginas) em `contents`,
    retorna apenas o último 'Total de Avisos de Cirurgia'.
    """
    last_controls = []
    for pages in content:
        # usa clean_content para separar linhas de controle
        _, controls = clean_content(pages)
        if controls:
            last_controls.append(controls[-1])
    return last_controls

# Uso:
# supondo que content seja uma lista onde cada item é as páginas de um PDF
last_totals = extract_last_controls_per_doc(content)
print(last_totals)
# → ['Total de Avisos de Cirurgia : 32', 'Total de Avisos de Cirurgia : 41']
# Out:
# []

# %%
def extract_data(page_lines):
    """
    Extrai a primeira data no formato 'DD/MM/YYYY' de uma página inteira.
    """
    for line in page_lines:
        m = re.match(r'\s*[Dd]ata\s*[:\-]\s*(\d{2}/\d{2}/\d{4})', line)
        if m:
            return m.group(1)
    return None

# %%
def extract_sala(line):
    """
    Se a linha começa com "Sala :", pega a última palavra,
    converte para int e retorna no formato "Sala X".
    """
    line = line.strip()
    if line.startswith("Sala :"):
        # ex: ["Sala", ":", "24", "-", "SALA", "1"] -> última palavra é "1"
        last = line.split()[-1]
        try:
            num = int(last)
            return f"Sala {num}"
        except ValueError:
            pass
    # Fallback genérico: captura "SALA X" em qualquer outro formato
    m = re.search(r"\bSALA\s*(\d+)\b", line, re.IGNORECASE)
    if m:
        num = int(m.group(1))
        return f"Sala {num}"
    return None

# %%
def extract_medico(lines):
    # 1) se houver rótulo explícito
    for line in lines:
        m = re.match(r'\s*[Mm]édico\s*[:\-]\s*(.+)', line)
        if m:
            return m.group(1).strip().title()

    # 2) pega a primeira linha que começa com horário
    record = next((l for l in lines if re.match(r'^\d{2}:\d{2}\s', l)), None)
    if record:
        # split na última ocorrência de 'Não' ou 'Sim'
        parts = re.split(r'\b(?:Não|Sim)\b', record, flags=re.IGNORECASE)
        name = parts[-1].strip()
        return name.title()

    return None

# %%
def extract_horario(lines):
    """
    Busca a primeira ocorrência de horário no formato 'HH:MM' em uma lista de linhas.
    """
    for line in lines:
        # Match de início de linha ou qualquer parte: HH:MM
        m = re.search(r'\b([01]\d|2[0-3]):([0-5]\d)\b', line)
        if m:
            return m.group(0)
    return None

# %%
def build_record(page_date, sala, lines):
    """
    Converte (sala, linhas) num dict chamando suas funções de extração.
    """
    return {
        'data'    : page_date,
        'horario'    : extract_horario(lines),
        'sala'       : sala,
        'medico'     : extract_medico(lines),
        # 'data'       : extract_data(lines),
        # 'cirurgia'   : extract_cirurgia(lines),
        # 'lateralidade': extract_lateralidade(lines),
        # 'anestesia'  : extract_anestesia(lines),
        # 'convenio'   : extract_convenio(lines),
        # 'observacao' : extract_observacao(lines),
    }

# %%
def parse_schedule(content):
    """
    Recebe content (lista de páginas, cada uma lista de linhas)
    e devolve uma lista de registros estruturados.
    """
    records = []

    for page in content:
        page_date = extract_data(page)
        current_sala = None
        current_block = None

        for line in page:
            # 1) atualiza a sala corrente
            sala = extract_sala(line)
            if sala:
                current_sala = sala
                continue

            # 2) nova cirurgia: linha que começa com HH:MM
            if re.match(r'^\d{2}:\d{2}\s', line):
                # salva o bloco anterior
                if current_block:
                    records.append(build_record(page_date, current_sala, current_block))
                # inicia novo bloco
                current_block = [line]
            else:
                # continua acumulando no bloco atual
                if current_block is not None:
                    current_block.append(line)

    # 3) salva o último bloco
    if current_block:
        records.append(build_record(page_date, current_sala, current_block))

    return records

# %%
# Uso:
escala = parse_schedule(content)
print(f"Total de cirurgias: {len(escala)}")
for r in escala:
    print(r)
# Out:
# Total de cirurgias: 72
# {'data': '30/04/2025', 'horario': '15:00', 'sala': 'Sala 1', 'medico': 'Amanda Schnorr'}
# {'data': '30/04/2025', 'horario': '16:00', 'sala': 'Sala 2', 'medico': 'Amanda Schnorr'}
# {'data': '30/04/2025', 'horario': '15:30', 'sala': 'Sala 2', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '16:00', 'sala': 'Sala 2', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '16:30', 'sala': 'Sala 2', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '17:00', 'sala': 'Sala 2', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '17:30', 'sala': 'Sala 2', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '18:00', 'sala': 'Sala 2', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '18:30', 'sala': 'Sala 2', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '19:00', 'sala': 'Sala 2', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '19:30', 'sala': 'Sala 2', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '20:00', 'sala': 'Sala 2', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '20:30', 'sala': 'Sala 2', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '21:00', 'sala': 'Sala 3', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '08:00', 'sala': 'Sala 3', 'medico': 'Julia Maria Lunelli'}
# {'data': '30/04/2025', 'horario': '09:00', 'sala': 'Sala 3', 'medico': 'Julia Maria Lunelli'}
# {'data': '30/04/2025', 'horario': '17:00', 'sala': 'Sala 5', 'medico': 'Luiz Eduardo Osowski'}
# {'data': '30/04/2025', 'horario': '08:00', 'sala': 'Sala 5', 'medico': 'Bruna Nunes Pagano'}
# {'data': '30/04/2025', 'horario': '09:00', 'sala': 'Sala 5', 'medico': 'Bruna Nunes Pagano'}
# {'data': '30/04/2025', 'horario': '10:00', 'sala': 'Sala 5', 'medico': 'Bruna Nunes Pagano'}
# {'data': '30/04/2025', 'horario': '11:00', 'sala': 'Sala 5', 'medico': 'Bruna Nunes Pagano'}
# {'data': '30/04/2025', 'horario': '12:00', 'sala': 'Sala 5', 'medico': 'Bruna Nunes Pagano'}
# {'data': '30/04/2025', 'horario': '15:00', 'sala': 'Sala 8', 'medico': 'Karla Linck Scheid'}
# {'data': '30/04/2025', 'horario': '08:00', 'sala': 'Sala 8', 'medico': 'Mateus Luis Riedi'}
# {'data': '30/04/2025', 'horario': '08:15', 'sala': 'Sala 8', 'medico': 'Mateus Luis Riedi'}
# {'data': '30/04/2025', 'horario': '08:30', 'sala': 'Sala 8', 'medico': 'Mateus Luis Riedi'}
# {'data': '30/04/2025', 'horario': '08:45', 'sala': 'Sala 8', 'medico': 'Eduardo Taube Borre'}
# {'data': '30/04/2025', 'horario': '09:00', 'sala': 'Sala 8', 'medico': 'Eduardo Taube Borre'}
# {'data': '30/04/2025', 'horario': '09:15', 'sala': 'Sala 8', 'medico': 'Mateus Luis Riedi'}
# {'data': '30/04/2025', 'horario': '09:30', 'sala': 'Sala 8', 'medico': 'Mateus Luis Riedi'}
# {'data': '30/04/2025', 'horario': '09:45', 'sala': 'Sala 8', 'medico': 'Mateus Luis Riedi'}
# {'data': '30/04/2025', 'horario': '09:00', 'sala': 'Sala 1', 'medico': 'Felipe Fernandes Nicola'}
# {'data': '30/04/2025', 'horario': '13:00', 'sala': 'Sala 1', 'medico': 'Amanda Schnorr'}
# {'data': '30/04/2025', 'horario': '13:30', 'sala': 'Sala 1', 'medico': 'Amanda Schnorr'}
# {'data': '30/04/2025', 'horario': '14:00', 'sala': 'Sala 1', 'medico': 'Amanda Schnorr'}
# {'data': '30/04/2025', 'horario': '14:30', 'sala': 'Sala 1', 'medico': 'Amanda Schnorr'}
# {'data': '30/04/2025', 'horario': '15:00', 'sala': 'Sala 2', 'medico': 'Amanda Schnorr'}
# {'data': '30/04/2025', 'horario': '07:30', 'sala': 'Sala 2', 'medico': 'Otavio De Azevedo Magalhaes'}
# {'data': '30/04/2025', 'horario': '08:30', 'sala': 'Sala 2', 'medico': 'Otavio De Azevedo Magalhaes'}
# {'data': '30/04/2025', 'horario': '10:00', 'sala': 'Sala 2', 'medico': 'Otavio De Azevedo Magalhaes'}
# {'data': '30/04/2025', 'horario': '12:00', 'sala': 'Sala 2', 'medico': 'Adriano Calcagnotto Garcia'}
# {'data': '30/04/2025', 'horario': '12:30', 'sala': 'Sala 2', 'medico': 'Adriano Calcagnotto Garcia'}
# {'data': '30/04/2025', 'horario': '15:00', 'sala': 'Sala 3', 'medico': 'Anais Back Da Silva'}
# {'data': '30/04/2025', 'horario': '10:00', 'sala': 'Sala 3', 'medico': 'Julia Maria Lunelli'}
# {'data': '30/04/2025', 'horario': '13:00', 'sala': 'Sala 3', 'medico': 'Karoliny Krause Monico'}
# {'data': '30/04/2025', 'horario': '18:00', 'sala': 'Sala 4', 'medico': 'Delano Jorge'}
# {'data': '30/04/2025', 'horario': '08:00', 'sala': 'Sala 4', 'medico': 'Daniel Emilio Valenzuela Chirinos'}
# {'data': '30/04/2025', 'horario': '09:30', 'sala': 'Sala 4', 'medico': 'Julia Teixeira Leite Pereira'}
# {'data': '30/04/2025', 'horario': '11:30', 'sala': 'Sala 4', 'medico': 'Victoria D Azevedo Silveira'}
# {'data': '30/04/2025', 'horario': '12:00', 'sala': 'Sala 4', 'medico': 'Victoria D Azevedo Silveira'}
# {'data': '30/04/2025', 'horario': '12:30', 'sala': 'Sala 4', 'medico': 'Victoria D Azevedo Silveira'}
# {'data': '30/04/2025', 'horario': '13:00', 'sala': 'Sala 4', 'medico': 'Victoria D Azevedo Silveira'}
# {'data': '30/04/2025', 'horario': '14:00', 'sala': 'Sala 4', 'medico': 'James Da Costa Marchiori'}
# {'data': '30/04/2025', 'horario': '15:00', 'sala': 'Sala 5', 'medico': 'James Da Costa Marchiori'}
# {'data': '30/04/2025', 'horario': '13:00', 'sala': 'Sala 5', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '13:30', 'sala': 'Sala 5', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '17:30', 'sala': 'Sala 5', 'medico': 'Gabriel Dos Santos Gatti'}
# {'data': '30/04/2025', 'horario': '18:00', 'sala': 'Sala 5', 'medico': 'Gabriel Dos Santos Gatti'}
# {'data': '30/04/2025', 'horario': '18:30', 'sala': 'Sala 8', 'medico': 'Gabriel Dos Santos Gatti'}
# {'data': '30/04/2025', 'horario': '12:30', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '12:45', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '13:00', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '13:15', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '13:30', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '13:45', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '14:00', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '14:15', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '14:30', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '14:45', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '15:00', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '15:15', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}
# {'data': '30/04/2025', 'horario': '15:30', 'sala': 'Sala 8', 'medico': 'Gustavo Sangalli Kussler'}

# %%
def extract_cirurgia_segments(content):
    """
    Para cada página em `content` (lista de listas de linhas),
    retorna uma lista de listas com todas as linhas de cirurgia
    (entre 'Cirurgia...' e a próxima 'Observação...').
    """
    segments = []
    for page in content:
        capturing = False
        buffer = []
        for line in page:
            text = line.strip().lower()
            # Inicia captura após encontrar linha que começa com 'cirurgia'
            if text.startswith('cirurgia'):
                capturing = True
                buffer = []
                continue
            # Encerra captura quando encontrar 'observação' e salva o segmento
            if capturing and text.startswith('observação'):
                capturing = False
                if buffer:
                    segments.append(buffer[:])
                continue
            # Se estiver capturando, adiciona a linha completa
            if capturing:
                buffer.append(line)
    return segments

# Exemplo de uso:
cirurgias = extract_cirurgia_segments(content)
for idx, seg in enumerate(cirurgias, 1):
    for l in seg:
        print(l)
# Out:
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO Não Cadastrado
# CORREÇÃO CIRÚRGICA DO ESTRABISMO (ATE 2 MUSCULOS) Bilateral SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# FACECTOMIA COM IMPLANTE DE LENTE INTRA-OCULAR Direita SUS - AMBULATORIO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# 2 - FACOEMULSIFICACAO C/ IMPLANTE DE LENTE INTRA-OCULAR DOB Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# RETINOPEXIA C/INTROF ESCLERAL (QQ TECNIC Esquerda SUS - INTERNACAO/PLANO UNICO Não Cadastrado
# VITRECTOMIA POSTERIOR COM INFUSAO DE PERFLUO/OLEO DE SILI Esquerda SUS - INTERNACAO/PLANO UNICO Não Cadastrado
# TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Esquerda SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# TRATAMENTO MEDICAMENTOSO DE DOENÇA DA RETINA Direita SUS - AMBULATORIO/PLANO UNICO Não Cadastrado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda CANOASPREV/PLANO UNICO Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 5 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 3 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 5 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 3 Autorizado
# PCT PART TRATAMENTO OCULAR QUIMIOTERAPICO Direita PARTICULAR Não Cadastrado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda UNIMED HOSPITAL/UNIMAX Autorizado
# IRIDECTOMIA (LASER OU CIRURGICA) - MONOCULAR Esquerda SULMED/PLANO UNICO Autorizado
# TRANSPLANTE DE CORNEA - COMBINADA Esquerda SULMED/PLANO UNICO Autorizado
# RECONSTRUCAO CAMARA ANTERIOR Esquerda UNIMED HOSPITAL/UNIPART Autorizado
# CANTOPLASTIA LATERAL Bilateral UNIMED HOSPITAL Autorizado
# DERMATOCALAZE OU BLEFAROCALAZE – UNILATERAL Bilateral UNIMED HOSPITAL Autorizado
# PCT PART BLEFAROPLASTIA SUPERIOR OU INFERIOR AO Bilateral PARTICULAR Não Cadastrado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS/CATEGORIA 5 Autorizado
# PCT PART ESTRABISMO (MONO) Direita PARTICULAR Não Cadastrado
# RECONST. DE VIAS LACRIMAIS COM SILICONE OU OUTRO MATERIAL Esquerda IPERGS/CATEGORIA 5 Autorizado
# ECTROPIO Bilateral IPERGS/CATEGORIA 4 Autorizado
# PALPEBRA - RECONSTRUCAO PARCIAL (COM OU SEM RESSECCAO D Bilateral IPERGS/CATEGORIA 4 Autorizado
# RECONST. DE VIAS LACRIMAIS COM SILICONE OU OUTRO MATERIAL Bilateral IPERGS/CATEGORIA 4 Autorizado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita DOCTOR CLIN Autorizado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda IPERGS/CATEGORIA 5 Autorizado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda CASSI/PLANO ASSOCIADO Autorizado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS Autorizado
# PCT PART FACECTOMIA COM LENTE INTRA-OCULAR (S/LIO) Direita PARTICULAR Não Cadastrado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS/CATEGORIA 5 Autorizado
# ESTRABISMO HORIZONTAL - MONOCULAR - TTO CIRURGICO Esquerda UNIMED HOSPITAL Autorizado
# ESTRABISMO HORIZONTAL - MONOCULAR - TTO CIRURGICO Esquerda UNIMED HOSPITAL Autorizado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS/CATEGORIA 2 Autorizado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda IPERGS/CATEGORIA 5 Autorizado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS Autorizado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Direita IPERGS/CATEGORIA 5 Autorizado
# FACECTOMIA COM LENTE INTRA-OCULAR COM FACOEMULSIFICACAO Esquerda IPERGS/CATEGORIA 5 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 5 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 5 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 5 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 5 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 5 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 3 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 3 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 3 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Bilateral ISSEG/PLANO UNICO Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita UNIMED HOSPITAL/CO-IRMA Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Direita IPERGS/CATEGORIA 5 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS/CATEGORIA 5 Autorizado
# TRATAMENTO OCULAR QUIMIOTERAPICO COM ANTI-ANGIOGENICO. P Esquerda IPERGS Autorizado
